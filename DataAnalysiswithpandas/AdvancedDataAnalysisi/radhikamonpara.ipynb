# %%
import os
os.listdir()
# Out:
# ['.eclipse',
#  'Music',
#  'Testings.ipynb',
#  '.canopy_runtimes.json',
#  '.DS_Store',
#  'eclipse',
#  'university_assignments',
#  'Transcript copy.jpg',
#  '.CFUserTextEncoding',
#  'REPORT_semaphore.pdf',
#  '.tooling',
#  'scholarship',
#  'TP_sujet.pdf',
#  'Untitled.ipynb',
#  'Stages',
#  'Hoaremonitor.docx',
#  'finallestcv.pdf',
#  'Pictures',
#  '.atom',
#  'City.pdf',
#  'pythondictionary',
#  'supermarkets.json',
#  'report_Combine.pdf',
#  'MacKeeper Backups',
#  'Transcript.jpg',
#  '.p2',
#  '.ipython',
#  '~$ternResume.docx',
#  'Desktop',
#  'Library',
#  'eclipse-workspace',
#  '.matplotlib',
#  'coverLetter.pdf',
#  '.oracle_jre_usage',
#  'supermarkets.csv',
#  '.emulator_console_auth_token',
#  'AAprac3python.py',
#  'README',
#  'ScholarCV.pdf',
#  '.bash_profile.pysave',
#  'CVairbus.docx',
#  '.android',
#  '.bash_sessions',
#  'supermarkets-semi-colons.txt',
#  'jupyternotebooktext',
#  'Public',
#  'tsp_s1_v3.txt',
#  '.dropbox',
#  '.idlerc',
# ...

# %%
import pandas

# %%
df1=pandas.read_csv("supermarkets.csv")
df1.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2=pandas.read_json("supermarkets.json")
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3=pandas.read_excel("supermarkets.xlsx")
df3
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df4=pandas.read_csv("supermarkets-commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5=pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5 # you can also pass url of the file if it is available online.. into "file online.csv" em
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df2.set_index("Address")
df2
list(df2.loc[:,"Employees"])
# Out:
# [8, 15, 25, 10, 12, 20]

# %%
df2.iloc[3,1:3]
# Out:
# City       San Francisco
# Country              USA
# Name: 3, dtype: object

# %%
df2.drop("City",1)
# Out:
#            Address Country  Employees  ID         Name             State
# 0     3666 21st St     USA          8   1      Madeira          CA 94114
# 1   735 Dolores St     USA         15   2  Bready Shop          CA 94119
# 2      332 Hill St     USA         25   3  Super River  California 94114
# 3     3995 23rd St     USA         10   4   Ben's Shop          CA 94114
# 4  1056 Sanchez St     USA         12   5      Sanchez        California
# 5  551 Alvarado St     USA         20   6   Richvalley          CA 94114

# %%
df2.drop(df2.index[0:3],0)
# Out:
#            Address           City Country  Employees  ID        Name  \
# 3     3995 23rd St  San Francisco     USA         10   4  Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5     Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6  Richvalley
#
#         State
# 3    CA 94114
# 4  California
# 5    CA 94114

# %%
df2.drop(df2.columns[0:3],1)
# Out:
#    Employees  ID         Name             State
# 0          8   1      Madeira          CA 94114
# 1         15   2  Bready Shop          CA 94119
# 2         25   3  Super River  California 94114
# 3         10   4   Ben's Shop          CA 94114
# 4         12   5      Sanchez        California
# 5         20   6   Richvalley          CA 94114

# %%
df2.columns
# Out:
# Index(['Address', 'City', 'Country', 'Employees', 'ID', 'Name', 'State'], dtype='object')

# %%
df2["Continent"]=["North Anerica","nbda","ad","vsagv","xvgsv","cdsj"]
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State      Continent
# 0          CA 94114  North Anerica
# 1          CA 94119           nbda
# 2  California 94114             ad
# 3          CA 94114          vsagv
# 4        California          xvgsv
# 5          CA 94114           cdsj

# %%
df2["Continent"]=df2["Name"]+","+"North Anerica"
df02=df2.T
df02
# Out:
#                                0                          1  \
# Address             3666 21st St             735 Dolores St
# City               San Francisco              San Francisco
# Country                      USA                        USA
# Employees                      8                         15
# ID                             1                          2
# Name                     Madeira                Bready Shop
# State                   CA 94114                   CA 94119
# Continent  Madeira,North Anerica  Bready Shop,North Anerica
#
#                                    2                         3  \
# Address                  332 Hill St              3995 23rd St
# City                   San Francisco             San Francisco
# Country                          USA                       USA
# Employees                         25                        10
# ID                                 3                         4
# ...

# %%
df2=df02.T

# %%
df2
# Out:
#            Address           City Country Employees ID         Name  \
# 0     3666 21st St  San Francisco     USA         8  1      Madeira
# 1   735 Dolores St  San Francisco     USA        15  2  Bready Shop
# 2      332 Hill St  San Francisco     USA        25  3  Super River
# 3     3995 23rd St  San Francisco     USA        10  4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA        12  5      Sanchez
# 5  551 Alvarado St  San Francisco     USA        20  6   Richvalley
#
#               State                  Continent
# 0          CA 94114      Madeira,North Anerica
# 1          CA 94119  Bready Shop,North Anerica
# 2  California 94114  Super River,North Anerica
# 3          CA 94114   Ben's Shop,North Anerica
# 4        California      Sanchez,North Anerica
# 5          CA 94114   Richvalley,North Anerica

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas
df=pandas.read_csv("supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"]=df["Address"]+","+df["City"]+","+ df["State"]+","+ df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 1   2  735 Dolores St,San Francisco,CA 94119,USA,San ...  San Francisco
# 2   3  332 Hill St,San Francisco,California 94114,USA...  San Francisco
# 3   4  3995 23rd St,San Francisco,CA 94114,USA,San Fr...  San Francisco
# 4   5  1056 Sanchez St,San Francisco,California,USA,S...  San Francisco
# 5   6  551 Alvarado St,San Francisco,CA 94114,USA,San...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
from geopy.geocoders import ArcGIS
nom=ArcGIS()
n=nom.geocode("3995 23rd St","San Francisco","CA 94114")
df["Coordinates"]=df["Address"].apply(nom.geocode)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     343         try:
# --> 344             page = requester(req, timeout=timeout, **kwargs)
#     345         except Exception as error:
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# ...

# %%
df.Coordinates[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-99-2e445ce25217> in <module>
# ----> 1 df.Coordinates[0]
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Coordinates'
